# %%
from bs4 import BeautifulSoup
import requests
import os
import numpy as np
import pandas as pd
import openpyxl
import re

# %%
def prettyprint(input_string):
    output_string = ''.join([' ' + char if (char.isupper() or char in '$') and prev_char!= ' ' else char for prev_char, char in zip('_' + input_string, input_string)])
    output_string = output_string.lstrip()  # Remove leading space if any
    #print(output_string)
    return(output_string)

# %%
def clean_role(input_string):
    # Remove special characters and spaces by replacing them with a single underscore
    cleaned_string = re.sub(r'[^a-zA-Z0-9]+', '_', input_string)
    
    return cleaned_string

# %%
def Scrape(company,role,link,posted,index):

    html_text = requests.get(link).text
    soup = BeautifulSoup(html_text,'lxml')

    elements = soup.find_all('div', class_='text-left')
    L=[element for element in elements]
    L= L[1:]

    with open(f'files/{index}.{company}.{role}.txt', 'w', encoding="utf-8") as f:
        f.write(f'{company}: {role}  ------- {posted}\n \n')

        for element in L:
            element= element.text

            f.write(prettyprint(element))
            f.write('\n')
            f.write('---------------------- \n')
        file= f'files/{index}.{company}.{role}.txt'
    return file

# %%
filepath = "data/updated_data.csv"
data = pd.read_csv(filepath)
data.head()
# Out:
#          Companies                                              Roles  \
# 0           Zocdoc                            Data Engineering Intern
# 1          Workiva  2024 Summer – Machine Learning Engineering Intern
# 2  Western Digital               Firmware Engineer Intern - Front End
# 3           Virtru                        Security Engineering Intern
# 4           Virtru                                         SRE Intern
#
#                                             Location Posted  \
# 0                                                NYC  7-Feb
# 1  <details><summary>**8 locations**</summary>Mis...  7-Feb
# 2                                       Milpitas, CA  7-Feb
# 3                                     Washington, DC  7-Feb
# 4                                     Washington, DC  7-Feb
#
#                                         Applications  \
# 0  https://www.zocdoc.com/about/careers/?job_id=5...
# 1  https://workiva.wd1.myworkdayjobs.com/careers/...
# 2  https://jobs.smartrecruiters.com/WesternDigita...
# 3  https://boards.greenhouse.io/virtru/jobs/43664...
# 4  https://boards.greenhouse.io/virtru/jobs/43646...
#
#                                                Links
# 0  https://simplify.jobs/p/a821846a-9aa8-472c-a82...
# 1  https://simplify.jobs/p/b36d60c7-01f7-4090-b8e...
# 2  https://simplify.jobs/p/8ec1a303-d113-4872-8d9...
# 3  https://simplify.jobs/p/cce7150b-9f46-4912-a0e...
# 4  https://simplify.jobs/p/303a000a-4e62-4c30-857...

# %%
for index, row in data.iterrows():
    Company= clean_role(row.iloc[0])
    Role= clean_role(row.iloc[1])
    Link= row.iloc[5]
    Posted= row.iloc[3]
    Scrape(Company,Role,Link,Posted,index)
    print(f'  ------{index}------file--------------------')
# Out:
#   ------0------file--------------------
#   ------1------file--------------------
#   ------2------file--------------------
#   ------3------file--------------------
#   ------4------file--------------------
#   ------5------file--------------------
#   ------6------file--------------------
#   ------7------file--------------------
#   ------8------file--------------------
#   ------9------file--------------------
#   ------10------file--------------------
#   ------11------file--------------------
#   ------12------file--------------------
#   ------13------file--------------------
#   ------14------file--------------------
#   ------15------file--------------------
#   ------16------file--------------------
#   ------17------file--------------------
#   ------18------file--------------------
#   ------19------file--------------------
#   ------20------file--------------------
#   ------21------file--------------------
#   ------22------file--------------------
#   ------23------file--------------------
#   ------24------file--------------------
#   ------25------file--------------------
#   ------26------file--------------------
#   ------27------file--------------------
#   ------28------file--------------------
#   ------29------file--------------------
#   ------30------file--------------------
#   ------31------file--------------------
#   ------32------file--------------------
#   ------33------file--------------------
#   ------34------file--------------------
#   ------35------file--------------------
#   ------36------file--------------------
#   ------37------file--------------------
#   ------38------file--------------------
#   ------39------file--------------------
#   ------40------file--------------------
#   ------41------file--------------------
#   ------42------file--------------------
#   ------43------file--------------------
#   ------44------file--------------------
#   ------45------file--------------------
#   ------46------file--------------------
#   ------47------file--------------------
#   ------48------file--------------------
#   ------49------file--------------------
#   ------50------file--------------------
#   ------51------file--------------------
#   ------52------file--------------------
#   ------53------file--------------------
#   ------54------file--------------------
#   ------55------file--------------------
#   ------56------file--------------------
#   ------57------file--------------------
#   ------58------file--------------------
#   ------59------file--------------------
#   ------60------file--------------------
#   ------61------file--------------------
#   ------62------file--------------------
#   ------63------file--------------------
#   ------64------file--------------------
#   ------65------file--------------------
#   ------66------file--------------------
#   ------67------file--------------------
#   ------68------file--------------------
#   ------69------file--------------------
#   ------70------file--------------------
#   ------71------file--------------------
#   ------72------file--------------------
#   ------73------file--------------------
#   ------74------file--------------------
#   ------75------file--------------------
#   ------76------file--------------------
#   ------77------file--------------------
#   ------78------file--------------------
#   ------79------file--------------------
#   ------80------file--------------------
#   ------81------file--------------------
#   ------82------file--------------------
#   ------83------file--------------------
#   ------84------file--------------------
#   ------85------file--------------------
#   ------86------file--------------------
#   ------87------file--------------------
#   ------88------file--------------------
#   ------89------file--------------------
#   ------90------file--------------------
#   ------91------file--------------------
#   ------92------file--------------------
#   ------93------file--------------------
#   ------94------file--------------------
#   ------95------file--------------------
#   ------96------file--------------------
#   ------97------file--------------------
#   ------98------file--------------------
#   ------99------file--------------------
#   ------100------file--------------------
#   ------101------file--------------------
#   ------102------file--------------------
#   ------103------file--------------------
#   ------104------file--------------------
#   ------105------file--------------------
#   ------106------file--------------------
#   ------107------file--------------------
#   ------108------file--------------------
#   ------109------file--------------------
#   ------110------file--------------------
#   ------111------file--------------------
#   ------112------file--------------------
#   ------113------file--------------------
#   ------114------file--------------------
#   ------115------file--------------------
#   ------116------file--------------------
#   ------117------file--------------------
#   ------118------file--------------------
#   ------119------file--------------------
#   ------120------file--------------------
#   ------121------file--------------------
#   ------122------file--------------------
#   ------123------file--------------------
#   ------124------file--------------------
#   ------125------file--------------------
#   ------126------file--------------------
#   ------127------file--------------------
#   ------128------file--------------------
#   ------129------file--------------------
#   ------130------file--------------------
#   ------131------file--------------------
#   ------132------file--------------------
#   ------133------file--------------------
#   ------134------file--------------------
#   ------135------file--------------------
#   ------136------file--------------------
#   ------137------file--------------------
#   ------138------file--------------------
#   ------139------file--------------------
#   ------140------file--------------------
#   ------141------file--------------------
#   ------142------file--------------------
#   ------143------file--------------------
#   ------144------file--------------------
#   ------145------file--------------------
#   ------146------file--------------------
#   ------147------file--------------------
#   ------148------file--------------------
#   ------149------file--------------------
#   ------150------file--------------------
#   ------151------file--------------------
#   ------152------file--------------------
#   ------153------file--------------------
#   ------154------file--------------------
#   ------155------file--------------------
#   ------156------file--------------------
#   ------157------file--------------------
#   ------158------file--------------------
#   ------159------file--------------------
#   ------160------file--------------------
#   ------161------file--------------------
#   ------162------file--------------------
#   ------163------file--------------------
#   ------164------file--------------------
#   ------165------file--------------------
#   ------166------file--------------------
#   ------167------file--------------------
#   ------168------file--------------------
#   ------169------file--------------------
#   ------170------file--------------------
#   ------171------file--------------------
#   ------172------file--------------------
#   ------173------file--------------------
#   ------174------file--------------------
#   ------175------file--------------------
#   ------176------file--------------------
#   ------177------file--------------------
#   ------178------file--------------------
#   ------179------file--------------------
#   ------180------file--------------------
#   ------181------file--------------------
#   ------182------file--------------------
#   ------183------file--------------------
#   ------184------file--------------------
#   ------185------file--------------------
#   ------186------file--------------------
#   ------187------file--------------------
#   ------188------file--------------------
#   ------189------file--------------------
#   ------190------file--------------------
#   ------191------file--------------------
#   ------192------file--------------------
#   ------193------file--------------------
#   ------194------file--------------------
#   ------195------file--------------------
#   ------196------file--------------------
#   ------197------file--------------------
#   ------198------file--------------------
#   ------199------file--------------------
#   ------200------file--------------------
#   ------201------file--------------------
#   ------202------file--------------------
#   ------203------file--------------------
#   ------204------file--------------------
#   ------205------file--------------------
#   ------206------file--------------------
#   ------207------file--------------------
#   ------208------file--------------------
#   ------209------file--------------------
#   ------210------file--------------------
#   ------211------file--------------------
#   ------212------file--------------------
#   ------213------file--------------------
#   ------214------file--------------------
#   ------215------file--------------------
#   ------216------file--------------------
#   ------217------file--------------------
#   ------218------file--------------------
#   ------219------file--------------------
#   ------220------file--------------------
#   ------221------file--------------------
#   ------222------file--------------------
#   ------223------file--------------------
#   ------224------file--------------------
#   ------225------file--------------------
#   ------226------file--------------------
#   ------227------file--------------------
#   ------228------file--------------------
#   ------229------file--------------------
#   ------230------file--------------------
#   ------231------file--------------------
#   ------232------file--------------------
#   ------233------file--------------------
#   ------234------file--------------------
#   ------235------file--------------------
#   ------236------file--------------------
#   ------237------file--------------------
#   ------238------file--------------------
#   ------239------file--------------------
#   ------240------file--------------------
#   ------241------file--------------------
#   ------242------file--------------------

# %%
<div class="rounded bg-red-100 px-2 text-sm font-semibold text-red-600">INACTIVE</div>

# %%
# elements = soup.find_all('div', class_='text-left')
# L=[element for element in elements]
# L= L[1:]

# with open(f'files/{company}.{role}.txt', 'w', encoding="utf-8") as f:
#     f.write(f'{company}: {role}  ------- {posted}\n \n')

#     for element in L:
#         element= element.text

#         f.write(prettyprint(element))
#         f.write('\n')
#         f.write('---------------------- \n')
